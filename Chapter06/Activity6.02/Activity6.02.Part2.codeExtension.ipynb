# %% [markdown]
# ## Activity 6.02 - Part 2

# %%
from sklearn.neural_network import MLPClassifier
import pickle
import os

# %%
path = os.getcwd()+'/final_model.pkl'
file = open(path, 'rb')
model = pickle.load(file)

# %%
pred = model.predict([[42,2,0,0,1,2,1,0,5,8,380,1,-1,0]])
print(pred)
# Out:
# [0]
