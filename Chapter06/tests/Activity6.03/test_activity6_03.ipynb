# %%
import unittest
import numpy as np
import pandas as pd
import numpy.testing as np_testing
import pandas.testing as pd_testing
import os
import import_ipynb
from trainedModel import NN_Model

class Test(unittest.TestCase):

    def _dirname_if_file(self, filename):
        if os.path.isdir(filename):
            return filename
        else:
            return os.path.dirname(os.path.abspath(filename))

    def setUp(self):    
        import Activity6_03_codeExtension
        self.activity = Activity6_03_codeExtension
       
        self.age = 42
        self.job = 2
        self.marital = 0
        self.education = 0
        self.default = 1
        self.balance = 2
        self.housing = 1
        self.loan = 0
        self.day = 5
        self.month = 8
        self.duration = 380
        self.campaign = 1
        self.pdays = -1
        self.previous = 0

        self.model = NN_Model()
        
    def test_model(self):
        self.pred = self.model.predict(age=self.age, job=self.job, marital=self.marital, \
                    education=self.education, default=self.default, balance=self.balance, \
                    housing=self.housing, loan=self.loan, day=self.day, month=self.month, \
                    duration=self.duration, campaign=self.campaign, pdays=self.pdays, previous=self.previous)
        np_testing.assert_almost_equal(self.pred, self.activity.pred)

if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
